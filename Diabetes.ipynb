# %% [markdown]
# <a href="https://colab.research.google.com/github/Upendra4204/Upendra4204/blob/main/Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e7febd1c-5210-4e09-b9d7-37e328212d63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7febd1c-5210-4e09-b9d7-37e328212d63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
data=pd.read_csv('diabetes.csv')
df=pd.DataFrame(data)
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# Assuming 'df' is your DataFrame
# Assuming 'Target' is your target variable

# Calculate correlations with the target variable
correlations = df.corr()['Outcome'].abs()

# Set the correlation threshold
threshold = 0.2

# Filter features with correlation above the threshold
selected_features = correlations[correlations >= threshold].index

# Create a new DataFrame with selected features
new_df = df[selected_features]

# Display the new DataFrame
print(new_df)
# Out:
#      Pregnancies  Glucose   BMI  Age  Outcome
# 0              6      148  33.6   50        1
# 1              1       85  26.6   31        0
# 2              8      183  23.3   32        1
# 3              1       89  28.1   21        0
# 4              0      137  43.1   33        1
# ..           ...      ...   ...  ...      ...
# 763           10      101  32.9   63        0
# 764            2      122  36.8   27        0
# 765            5      121  26.2   30        0
# 766            1      126  30.1   47        1
# 767            1       93  30.4   23        0
#
# [768 rows x 5 columns]

# %%
df=new_df
df
# Out:
#      Pregnancies  Glucose   BMI  Age  Outcome
# 0              6      148  33.6   50        1
# 1              1       85  26.6   31        0
# 2              8      183  23.3   32        1
# 3              1       89  28.1   21        0
# 4              0      137  43.1   33        1
# ..           ...      ...   ...  ...      ...
# 763           10      101  32.9   63        0
# 764            2      122  36.8   27        0
# 765            5      121  26.2   30        0
# 766            1      126  30.1   47        1
# 767            1       93  30.4   23        0
#
# [768 rows x 5 columns]

# %%
def remove_outliers(df, Outcome):
    # Calculate the 20th and 80th percentiles
    lower_bound = df[Outcome].quantile(0.2)
    upper_bound = df[Outcome].quantile(0.8)

    # Remove rows with values below 20th percentile and above 80th percentile
    filtered_df = df[(df[Outcome] >= lower_bound) & (df[Outcome] <= upper_bound)]

    return filtered_df

# Call the function and assign the result to a variable named 'filtered_data'
filtered_data = remove_outliers(df, 'Outcome')

# Print the resulting DataFrame
print(filtered_data)
# Out:
#      Pregnancies  Glucose   BMI  Age  Outcome
# 0              6      148  33.6   50        1
# 1              1       85  26.6   31        0
# 2              8      183  23.3   32        1
# 3              1       89  28.1   21        0
# 4              0      137  43.1   33        1
# ..           ...      ...   ...  ...      ...
# 763           10      101  32.9   63        0
# 764            2      122  36.8   27        0
# 765            5      121  26.2   30        0
# 766            1      126  30.1   47        1
# 767            1       93  30.4   23        0
#
# [768 rows x 5 columns]

# %%
df=filtered_data

# %%
X=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
df1=np.log1p(X)
df1
# Out:
#      Pregnancies   Glucose       BMI       Age
# 0       1.945910  5.003946  3.543854  3.931826
# 1       0.693147  4.454347  3.317816  3.465736
# 2       2.197225  5.214936  3.190476  3.496508
# 3       0.693147  4.499810  3.370738  3.091042
# 4       0.000000  4.927254  3.786460  3.526361
# ..           ...       ...       ...       ...
# 763     2.397895  4.624973  3.523415  4.158883
# 764     1.098612  4.812184  3.632309  3.332205
# 765     1.791759  4.804021  3.303217  3.433987
# 766     0.693147  4.844187  3.437208  3.871201
# 767     0.693147  4.543295  3.446808  3.178054
#
# [768 rows x 4 columns]

# %%
df=pd.concat([df1,y],axis=1)
df.head(5)
# Out:
#    Pregnancies   Glucose       BMI       Age  Outcome
# 0     1.945910  5.003946  3.543854  3.931826        1
# 1     0.693147  4.454347  3.317816  3.465736        0
# 2     2.197225  5.214936  3.190476  3.496508        1
# 3     0.693147  4.499810  3.370738  3.091042        0
# 4     0.000000  4.927254  3.786460  3.526361        1

# %%
from imblearn.over_sampling import SMOTE

smote=SMOTE()
X_resampled,y_resampled=smote.fit_resample(X,y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_resampled,y_resampled,test_size=0.20,random_state=42)

# %%
print(pd.Series(y_resampled).value_counts(normalize=True))
# Out:
# 1    0.5
# 0    0.5
# Name: Outcome, dtype: float64

# %%
logistic_params = {
    'penalty': 'l2',           # Regularization type ('l1', 'l2', 'elasticnet', 'none')
    'C': 10,                  # Inverse of regularization strength (smaller values specify stronger regularization)
    'fit_intercept': True,      # Whether to calculate the intercept for this model
    'solver': 'lbfgs',         # Algorithm to use in the optimization problem ('newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga')
    'max_iter': 200,            # Maximum number of iterations for optimization
    'random_state': 42         # Seed for random number generation
}

# %%
model=LogisticRegression(**logistic_params)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
confusion_matrix=confusion_matrix(y_test,y_pred)

# %%
accuracy
# Out:
# 0.74

# %%
confusion_matrix
# Out:
# array([[72, 27],
#        [25, 76]])

# %%
from sklearn.model_selection import cross_val_score, KFold

# Assuming model is your machine learning model
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
cross_val_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring='accuracy')
print("Cross-Validation Results:", cross_val_results)
# Out:
# Cross-Validation Results: [0.75625 0.68125 0.725   0.73125 0.73125]

# %%
from sklearn.svm import SVC
svm_params = {
    'C': 10,                  # Regularization parameter (controls the trade-off between smooth decision boundary and classifying points correctly)
    'kernel': 'rbf',           # Kernel type ('linear', 'poly', 'rbf', 'sigmoid', etc.)
    'gamma': 'scale',          # Kernel coefficient ('scale' uses 1 / (n_features * X.var()) as gamma, 'auto' uses 1 / n_features)
    'degree': 3,               # Degree of the polynomial kernel function ('poly' kernel)
    'coef0': 0.0,              # Independent term in the kernel function ('poly' and 'sigmoid' kernels)
    'shrinking': True,         # Whether to use the shrinking heuristic
    'probability': False,      # Whether to enable probability estimates
    'tol': 1e-3,               # Tolerance for stopping criterion
    'class_weight': None,      # Class weights (dict or 'balanced')
    'random_state': 42         # Seed for random number generation
}
svc=SVC(**svm_params)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)

# %%
svc_acc=accuracy_score(y_test,y_pred)
print("svc-acc:",svc_acc)
# Out:
# svc-acc: 0.745

# %%
from sklearn.model_selection import GridSearchCV


# Define hyperparameters to tune
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'penalty': ['l1', 'l2'],
    'max_iter':[200,400,600,1000]
}

# GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Print the best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)

# Predict on the test set using the best model
y_pred = grid_search.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Best Hyperparameters: {'C': 0.01, 'max_iter': 200, 'penalty': 'l2'}
# Accuracy: 0.73
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 140 fits failed out of a total of 280.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 140 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
# ...

# %%
from sklearn.model_selection import GridSearchCV

# Define hyperparameters to tune
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto'],
}

# GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(svc, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Print the best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)

# Predict on the test set using the best model
y_pred = grid_search.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
